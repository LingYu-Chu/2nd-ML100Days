# %%
作業1
1. 你選的這組資料為何重要
預測機器是否將被惡意軟體攻擊，以提高安全性。
2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
Microsoft Malware Prediction
3. 蒐集而來的資料型態為何
csv
4. 這組資料想解決的問題如何評估
Submissions are evaluated on area under the ROC curve between the predicted probability and the observed label.

作業2
想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
分析出各時段客源最多的地點，以降低空車率
2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
資料庫GPS定位、蒐集GOOGLE尖峰路段
3. 蒐集而來的資料型態為何
csv格式：時間、星期、座標、地圖
4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
將每一時段不同地點的客源多寡進行分析，評估派車的數量以及該車的整日動線規劃

作業3

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 12.305

# %%
def mean_Square_Error(y, yq):
    mse = sum((y - yq)**2) / len(y)
    return mse

MSE = mean_Square_Error(y, y_hat)
print("The Mean absolute error is %.3f" % (MSE))
# Out:
# The Mean absolute error is 230.999
